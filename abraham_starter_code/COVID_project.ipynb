# %%
# importing modules and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
from pathlib import Path

# %%
df = pd.read_csv(Path('covid_deaths.csv'))
df
# Out:
#                   REGION  Key       Area  CENSUS_2010_TOTAL_POPULATION  \
# 0                Alabama    1      South                       4779736
# 1                 Alaska    2       West                        710231
# 2                Arizona    3       West                       6392017
# 3               Arkansas    4      South                       2915918
# 4             California    5       West                      37253956
# 5               Colorado    6       West                       5029196
# 6            Connecticut    7  Northeast                       3574097
# 7               Delaware    8      South                        897934
# 8   District of Columbia    9      South                        601723
# 9                Florida   10      South                      18801310
# 10               Georgia   11      South                       9687653
# 11                Hawaii   12       West                       1360301
# 12                 Idaho   13       West                       1567582
# 13              Illinois   14    Midwest                      12830632
# 14               Indiana   15    Midwest                       6483802
# 15                  Iowa   16    Midwest                       3046355
# 16                Kansas   17    Midwest                       2853118
# 17              Kentucky   18      South                       4339367
# 18             Louisiana   19      South                       4533372
# 19                 Maine   20  Northeast                       1328361
# 20              Maryland   21      South                       5773552
# 21         Massachusetts   22  Northeast                       6547629
# 22              Michigan   23    Midwest                       9883640
# 23             Minnesota   24    Midwest                       5303925
# 24           Mississippi   25      South                       2967297
# 25              Missouri   26    Midwest                       5988927
# 26               Montana   27       West                        989415
# 27              Nebraska   28    Midwest                       1826341
# 28                Nevada   29       West                       2700551
# 29         New Hampshire   30  Northeast                       1316470
# 30            New Jersey   31  Northeast                       8791894
# 31            New Mexico   32       West                       2059179
# 32              New York   33  Northeast                      19378102
# 33        North Carolina   34      South                       9535483
# 34          North Dakota   35    Midwest                        672591
# 35                  Ohio   36    Midwest                      11536504
# 36              Oklahoma   37      South                       3751351
# 37                Oregon   38       West                       3831074
# 38          Pennsylvania   39  Northeast                      12702379
# 39          Rhode Island   40  Northeast                       1052567
# 40        South Carolina   41      South                       4625364
# 41          South Dakota   42    Midwest                        814180
# 42             Tennessee   43      South                       6346105
# 43                 Texas   44      South                      25145561
# 44                  Utah   45       West                       2763885
# 45               Vermont   46  Northeast                        625741
# 46              Virginia   47      South                       8001024
# 47            Washington   48       West                       6724540
# 48         West Virginia   49      South                       1852994
# 49             Wisconsin   50    Midwest                       5686986
# 50               Wyoming   51       West                        563626
#
#     CENSUS_2010_STATE_DENSITY  CENSUS_2010_RANK  2020_STATE_DENSITY  \
# 0                        94.4                29                  97
# 1                         1.2                52                   1
# 2                        56.3                35                  65
# 3                        56.0                36                  58
# 4                       239.1                13                 256
# 5                        48.5                39                  56
# 6                       738.1                 6                 736
# 7                       460.8                 8                 504
# 8                      9856.5                 1               11815
# 9                       350.6                10                 410
# 10                      168.4                20                 288
# 11                      211.8                15                 220
# 12                       19.0                46                  22
# 13                      231.1                14                 228
# 14                      181.0                18                 188
# 15                       54.5                38                  57
# 16                       34.9                42                  36
# 17                      109.9                24                 114
# 18                      104.9                26                 108
# 19                       43.1                40                  44
# 20                      594.8                 7                 627
# 21                      839.4                 5                 894
# 22                      174.8                19                 178
# 23                       66.6                33                  72
# 24                       63.2                34                  64
# 25                       87.1                30                  90
# 26                        6.8                50                   7
# 27                       23.8                45                  25
# 28                       24.6                44                  29
# 29                      147.0                23                 153
# 30                     1195.5                 2                1215
# 31                       17.0                47                  17
# 32                      411.2                 9                 413
# 33                      196.1                17                 218
# 34                        9.7                49                  11
# 35                      282.3                12                 288
# 36                       54.7                37                  58
# 37                       39.9                41                  45
# 38                      283.9                11                 287
# 39                     1018.1                 4                1021
# 40                      153.9                22                 173
# 41                       10.7                48                  12
# 42                      153.9                21                 167
# 43                       96.3                28                 113
# 44                       33.6                43                  40
# 45                       67.9                32                  68
# 46                      202.6                16                 218
# 47                      101.2                27                 117
# 48                       77.1                31                  74
# 49                      105.0                25                 108
# 50                        5.8                51                   6
#
#     STATE_LAND_AREA                              Major_City_CBSA_Title  \
# 0             50645                              Mobile, AL Metro Area
# 1            570641                           Anchorage, AK Metro Area
# 2            113594               Phoenix-Mesa-Glendale, AZ Metro Area
# 3             52035   Fayetteville-Springdale-Rogers, AR-MO Metro Area
# 4            155779       San Francisco-Oakland-Fremont, CA Metro Area
# 5            103642            Denver-Aurora-Broomfield, CO Metro Area
# 6              4842         Bridgeport-Stamford-Norwalk, CT Metro Area
# 7              1949                               Dover, DE Metro Area
# 8                61  Washington-Arlington-Alexandria, DC-VA-MD-WV M...
# 9             53625  Miami-Fort Lauderdale-Pompano Beach, FL Metro ...
# 10            40861      Atlanta-Sandy Springs-Marietta, GA Metro Area
# 11             6423                            Honolulu, HI Metro Area
# 12            82643                           Pocatello, ID Metro Area
# 13            55519     Chicago-Joliet-Naperville, IL-IN-WI Metro Area
# 14            35826                           Lafayette, IN Metro Area
# 15            55857                           Iowa City, IA Metro Area
# 16            81759                            Lawrence, KS Metro Area
# 17            39486                   Lexington-Fayette, KY Metro Area
# 18            43204         New Orleans-Metairie-Kenner, LA Metro Area
# 19            30843                     Lewiston-Auburn, ME Metro Area
# 20             9707                    Baltimore-Towson, MD Metro Area
# 21             7800          Boston-Cambridge-Quincy, MA-NH Metro Area
# 22            56539              Detroit-Warren-Livonia, MI Metro Area
# 23            79627  Minneapolis-St. Paul-Bloomington, MN-WI Metro ...
# 24            46923                             Jackson, MS Metro Area
# 25            68742                Lansing-East Lansing, MI Metro Area
# 26           145546                      Kansas City, MO-KS Metro Area
# 27            76824                             Lincoln, NE Metro Area
# 28           109781                  Las Vegas-Paradise, NV Metro Area
# 29             8953                   Manchester-Nashua, NH Metro Area
# 30             7354                       Trenton-Ewing, NJ Metro Area
# 31           121298                         Albuquerque, NM Metro Area
# 32            47126  New York-Northern New Jersey-Long Island, NY-N...
# 33           148618     Charlotte-Gastonia-Rock Hill, NC-SC Metro Area
# 34            69001                            Fargo, ND-MN Metro Area
# 35            40861             Cleveland-Elyria-Mentor, OH Metro Area
# 36            68595                       Oklahoma City, OK Metro Area
# 37            95988     Portland-Vancouver-Hillsboro, OR-WA Metro Area
# 38            44743  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD Me...
# 39             1034  Providence-New Bedford-Fall River, RI-MA Metro...
# 40            30061  Charleston-North Charleston-Summerville, SC Me...
# 41            75811                         Sioux Falls, SD Metro Area
# 42            41235                       Memphis, TN-MS-AR Metro Area
# 43           261232                              Laredo, TX Metro Area
# 44            82170                      Salt Lake City, UT Metro Area
# 45             9217         Burlington-South Burlington, VT Metro Area
# 46            39490                            Richmond, VA Metro Area
# 47            66456             Seattle-Tacoma-Bellevue, WA Metro Area
# 48            24038                          Morgantown, WV Metro Area
# 49            54158       Milwaukee-Waukesha-West Allis, WI Metro Area
# 50            97093                              Casper, WY Metro Area
#
#     CBSA Code  ...  Census_Population_Over_60  \
# 0       33660  ...                    1149135
# 1       11260  ...                     134012
# 2       38060  ...                    1695429
# 3       22220  ...                     695572
# 4       41860  ...                    7963713
# 5       19740  ...                    1156858
# 6       14860  ...                     865770
# 7       20100  ...                     248295
# 8       47900  ...                     118779
# 9       33100  ...                    5765648
# 10      12060  ...                    2070692
# 11      26180  ...                     355338
# 12      38540  ...                     382826
# 13      16980  ...                    2804799
# 14      29140  ...                    1477824
# 15      26980  ...                     743615
# 16      29940  ...                     645949
# 17      30460  ...                    1026703
# 18      35380  ...                    1019862
# 19      30340  ...                     384322
# 20      12580  ...                    1324920
# 21      14460  ...                    1588116
# 22      19820  ...                    2421416
# 23      33460  ...                    1243961
# 24      27140  ...                     667073
# 25      29620  ...                    1448367
# 26      28140  ...                     279971
# 27      30700  ...                     423109
# 28      29820  ...                     661507
# 29      31700  ...                     346662
# 30      45940  ...                    2022272
# 31      10740  ...                     504653
# 32      35620  ...                    4480458
# 33      16740  ...                    2353499
# 34      22020  ...                     162220
# 35      17460  ...                    2792679
# 36      36420  ...                     857599
# 37      38900  ...                    1016180
# 38      37980  ...                    3227151
# 39      39300  ...                     257992
# 40      16700  ...                    1228275
# 41      43620  ...                     205307
# 42      32820  ...                    1550510
# 43      29700  ...                    5139025
# 44      41620  ...                     499149
# 45      15540  ...                     172909
# 46      40060  ...                    1847250
# 47      42660  ...                    1636420
# 48      34060  ...                     492418
# 49      33340  ...                    1391738
# 50      16220  ...                     137988
#
#     Census_Population_Over_60_Employment_Rate  \
# 0                                        0.24
# 1                                        0.35
# 2                                        0.24
# 3                                        0.25
# 4                                        0.29
# 5                                        0.32
# 6                                        0.34
# 7                                        0.28
# 8                                        0.31
# 9                                        0.24
# 10                                       0.28
# 11                                       0.32
# 12                                       0.26
# 13                                       0.29
# 14                                       0.29
# 15                                       0.32
# 16                                       0.31
# 17                                       0.24
# 18                                       0.26
# 19                                       0.30
# 20                                       0.33
# 21                                       0.33
# 22                                       0.25
# 23                                       0.31
# 24                                       0.24
# 25                                       0.27
# 26                                       0.31
# 27                                       0.35
# 28                                       0.27
# 29                                       0.34
# 30                                       0.33
# 31                                       0.24
# 32                                       0.29
# 33                                       0.27
# 34                                       0.32
# 35                                       0.28
# 36                                       0.28
# 37                                       0.25
# 38                                       0.29
# 39                                       0.31
# 40                                       0.25
# 41                                       0.35
# 42                                       0.27
# 43                                       0.30
# 44                                       0.30
# 45                                       0.36
# 46                                       0.31
# 47                                       0.28
# 48                                       0.21
# 49                                       0.29
# 50                                       0.32
#
#     Census_Total_Population_Over_16_Estimate  \
# 0                                    3854015
# 1                                     548676
# 2                                    5608516
# 3                                    2336993
# 4                                   31085639
# 5                                    4479249
# 6                                    2884868
# 7                                     773385
# 8                                     576927
# 9                                   17262966
# 10                                   8128931
# 11                                   1096009
# 12                                   1337554
# 13                                  10040920
# 14                                   5205600
# 15                                   2464341
# 16                                   2229203
# 17                                   3492675
# 18                                   3579169
# 19                                   1105382
# 20                                   4754654
# 21                                   5633413
# 22                                   7986376
# 23                                   4395381
# 24                                   2296728
# 25                                   4797181
# 26                                    843546
# 27                                   1477589
# 28                                   2385543
# 29                                   1112869
# 30                                   7080172
# 31                                   1639138
# 32                                  15709161
# 33                                   8154786
# 34                                    585782
# 35                                   9237632
# 36                                   3008712
# 37                                   3379241
# 38                                  10271420
# 39                                    865601
# 40                                   4012850
# 41                                    673526
# 42                                   5330967
# 43                                  21663694
# 44                                   2305534
# 45                                    519162
# 46                                   6642133
# 47                                   5946027
# 48                                   1459045
# 49                                   4621479
# 50                                    449840
#
#     Census_Total_Workers_Over_16_Estimate  \
# 0                                 2055708
# 1                                  337552
# 2                                 3155343
# 3                                 1297409
# 4                                18399115
# 5                                 2930149
# 6                                 1785761
# 7                                  449293
# 8                                  375487
# 9                                 9557108
# 10                                4847726
# 11                                 666501
# 12                                 791148
# 13                                6174906
# 14                                3171334
# 15                                1587362
# 16                                1418803
# 17                                1952946
# 18                                1978312
# 19                                 664351
# 20                                3034807
# 21                                3554798
# 22                                4611616
# 23                                2920543
# 24                                1207063
# 25                                2873163
# 26                                 511597
# 27                                 980815
# 28                                1418382
# 29                                 712442
# 30                                4386693
# 31                                 865888
# 32                                9287627
# 33                                4768759
# 34                                 392429
# 35                                5515839
# 36                                1758388
# 37                                1992019
# 38                                6129917
# 39                                 515707
# 40                                2268973
# 41                                 445146
# 42                                3076837
# 43                               13256665
# 44                                1510473
# 45                                 323581
# 46                                4103126
# 47                                3609979
# 48                                 726374
# 49                                2952361
# 50                                 280862
#
#     COMMUTE_Census_Worker_Drive_To_Work_Rate  \
# 0                                       0.86
# 1                                       0.68
# 2                                       0.76
# 3                                       0.83
# 4                                       0.74
# 5                                       0.75
# 6                                       0.78
# 7                                       0.80
# 8                                       0.34
# 9                                       0.79
# 10                                      0.79
# 11                                      0.67
# 12                                      0.80
# 13                                      0.73
# 14                                      0.83
# 15                                      0.82
# 16                                      0.82
# 17                                      0.83
# 18                                      0.83
# 19                                      0.78
# 20                                      0.74
# 21                                      0.70
# 22                                      0.82
# 23                                      0.78
# 24                                      0.86
# 25                                      0.82
# 26                                      0.75
# 27                                      0.82
# 28                                      0.78
# 29                                      0.81
# 30                                      0.71
# 31                                      0.79
# 32                                      0.53
# 33                                      0.81
# 34                                      0.82
# 35                                      0.82
# 36                                      0.83
# 37                                      0.72
# 38                                      0.76
# 39                                      0.82
# 40                                      0.82
# 41                                      0.81
# 42                                      0.83
# 43                                      0.81
# 44                                      0.76
# 45                                      0.75
# 46                                      0.77
# 47                                      0.71
# 48                                      0.83
# 49                                      0.82
# 50                                      0.76
#
#     COMMUTE_Census_Worker_Carpool_To_Work_Rate  \
# 0                                         0.08
# 1                                         0.12
# 2                                         0.11
# 3                                         0.10
# 4                                         0.10
# 5                                         0.09
# 6                                         0.08
# 7                                         0.09
# 8                                         0.05
# 9                                         0.09
# 10                                        0.09
# 11                                        0.15
# 12                                        0.09
# 13                                        0.08
# 14                                        0.09
# 15                                        0.08
# 16                                        0.09
# 17                                        0.09
# 18                                        0.09
# 19                                        0.10
# 20                                        0.09
# 21                                        0.07
# 22                                        0.09
# 23                                        0.08
# 24                                        0.09
# 25                                        0.09
# 26                                        0.09
# 27                                        0.09
# 28                                        0.11
# 29                                        0.07
# 30                                        0.08
# 31                                        0.11
# 32                                        0.06
# 33                                        0.09
# 34                                        0.09
# 35                                        0.08
# 36                                        0.10
# 37                                        0.10
# 38                                        0.09
# 39                                        0.08
# 40                                        0.10
# 41                                        0.09
# 42                                        0.09
# 43                                        0.10
# 44                                        0.11
# 45                                        0.09
# 46                                        0.09
# 47                                        0.10
# 48                                        0.09
# 49                                        0.08
# 50                                        0.10
#
#     COMMUTE_Census_Worker_Public_Transportation_Rate  \
# 0                                               0.00
# 1                                               0.01
# 2                                               0.02
# 3                                               0.00
# 4                                               0.05
# 5                                               0.03
# 6                                               0.05
# 7                                               0.02
# 8                                               0.35
# 9                                               0.02
# 10                                              0.02
# 11                                              0.06
# 12                                              0.01
# 13                                              0.09
# 14                                              0.01
# 15                                              0.01
# 16                                              0.01
# 17                                              0.01
# 18                                              0.01
# 19                                              0.01
# 20                                              0.08
# 21                                              0.10
# 22                                              0.01
# 23                                              0.04
# 24                                              0.00
# 25                                              0.01
# 26                                              0.01
# 27                                              0.01
# 28                                              0.03
# 29                                              0.01
# 30                                              0.12
# 31                                              0.01
# 32                                              0.28
# 33                                              0.01
# 34                                              0.01
# 35                                              0.02
# 36                                              0.00
# 37                                              0.04
# 38                                              0.06
# 39                                              0.02
# 40                                              0.01
# 41                                              0.00
# 42                                              0.01
# 43                                              0.01
# 44                                              0.02
# 45                                              0.01
# 46                                              0.05
# 47                                              0.07
# 48                                              0.01
# 49                                              0.02
# 50                                              0.01
#
#     COMMUTE_Census_Worker_Walk_Rate  \
# 0                              0.01
# 1                              0.08
# 2                              0.02
# 3                              0.02
# 4                              0.03
# 5                              0.03
# 6                              0.03
# 7                              0.02
# 8                              0.13
# 9                              0.01
# 10                             0.01
# 11                             0.03
# 12                             0.03
# 13                             0.03
# 14                             0.02
# 15                             0.03
# 16                             0.02
# 17                             0.02
# 18                             0.02
# 19                             0.04
# 20                             0.02
# 21                             0.05
# 22                             0.02
# 23                             0.03
# 24                             0.01
# 25                             0.02
# 26                             0.06
# 27                             0.03
# 28                             0.02
# 29                             0.03
# 30                             0.03
# 31                             0.02
# 32                             0.06
# 33                             0.02
# 34                             0.03
# 35                             0.02
# 36                             0.02
# 37                             0.04
# 38                             0.04
# 39                             0.03
# 40                             0.01
# 41                             0.03
# 42                             0.01
# 43                             0.01
# 44                             0.02
# 45                             0.05
# 46                             0.02
# 47                             0.04
# 48                             0.03
# 49                             0.03
# 50                             0.04
#
#     COMMUTE_Census_Worker_Taxicab_Motorcycle_Bicycle_Other_Rate  \
# 0                                                0.01
# 1                                                0.06
# 2                                                0.03
# 3                                                0.01
# 4                                                0.03
# 5                                                0.02
# 6                                                0.01
# 7                                                0.01
# 8                                                0.07
# 9                                                0.02
# 10                                               0.02
# 11                                               0.03
# 12                                               0.02
# 13                                               0.02
# 14                                               0.02
# 15                                               0.01
# 16                                               0.01
# 17                                               0.01
# 18                                               0.02
# 19                                               0.02
# 20                                               0.02
# 21                                               0.02
# 22                                               0.01
# 23                                               0.02
# 24                                               0.01
# 25                                               0.01
# 26                                               0.02
# 27                                               0.01
# 28                                               0.02
# 29                                               0.02
# 30                                               0.02
# 31                                               0.02
# 32                                               0.02
# 33                                               0.01
# 34                                               0.01
# 35                                               0.01
# 36                                               0.01
# 37                                               0.03
# 38                                               0.02
# 39                                               0.01
# 40                                               0.02
# 41                                               0.01
# 42                                               0.01
# 43                                               0.02
# 44                                               0.02
# 45                                               0.02
# 46                                               0.02
# 47                                               0.02
# 48                                               0.01
# 49                                               0.02
# 50                                               0.02
#
#    COMMUTE_Census_Work_At_Home_Rate
# 0                              0.03
# 1                              0.05
# 2                              0.07
# 3                              0.04
# 4                              0.06
# 5                              0.09
# 6                              0.06
# 7                              0.06
# 8                              0.06
# 9                              0.06
# 10                             0.06
# 11                             0.06
# 12                             0.06
# 13                             0.05
# 14                             0.04
# 15                             0.05
# 16                             0.05
# 17                             0.04
# 18                             0.03
# 19                             0.06
# 20                             0.05
# 21                             0.05
# 22                             0.04
# 23                             0.06
# 24                             0.03
# 25                             0.05
# 26                             0.07
# 27                             0.05
# 28                             0.04
# 29                             0.07
# 30                             0.05
# 31                             0.05
# 32                             0.05
# 33                             0.06
# 34                             0.04
# 35                             0.04
# 36                             0.04
# 37                             0.08
# 38                             0.05
# 39                             0.04
# 40                             0.05
# 41                             0.06
# 42                             0.05
# 43                             0.05
# 44                             0.07
# 45                             0.08
# 46                             0.06
# 47                             0.07
# 48                             0.03
# 49                             0.05
# 50                             0.06
#
# [51 rows x 65 columns]

# %%
df.drop(['Key','CENSUS_2010_RANK', '2020_STATE_DENSITY','STATE_LAND_AREA', 'CBSA Code', 'Census_Population_Over_60','Census_Population_Over_60_Employment_Rate'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#        REGION   Area  CENSUS_2010_TOTAL_POPULATION  CENSUS_2010_STATE_DENSITY  \
# 0     Alabama  South                       4779736                       94.4
# 1      Alaska   West                        710231                        1.2
# 2     Arizona   West                       6392017                       56.3
# 3    Arkansas  South                       2915918                       56.0
# 4  California   West                      37253956                      239.1
#
#                               Major_City_CBSA_Title  \
# 0                             Mobile, AL Metro Area
# 1                          Anchorage, AK Metro Area
# 2              Phoenix-Mesa-Glendale, AZ Metro Area
# 3  Fayetteville-Springdale-Rogers, AR-MO Metro Area
# 4      San Francisco-Oakland-Fremont, CA Metro Area
#
#    CBSA_Major_City_Population_2010  CBSA_Major_City_max_weighted_density  \
# 0                           412992                                1659.3
# 1                           380821                                3006.9
# 2                          4192887                                4394.9
# 3                           463204                                1114.8
# 4                          4335391                               12144.9
#
#    CBSA_Major_City_mean_pop_density  Covid_Positive  Covid_Negative  ...  \
# 0                       1056.681818             981            6298  ...
# 1                       2035.000000             119            3594  ...
# 2                       1838.788889            1289           18082  ...
# 3                        931.666667             523            5959  ...
# 4                       4684.784615            7482           21772  ...
#
#    BRFSS_55_64_Other_Cancer_Rate  BRFSS_65_plus_Other_Cancer_Rate  \
# 0                       0.008910                         0.015471
# 1                       0.004340                         0.010168
# 2                       0.006308                         0.013680
# 3                       0.008787                         0.016704
# 4                       0.004582                         0.009686
#
#    Census_Total_Population_Over_16_Estimate  \
# 0                                   3854015
# 1                                    548676
# 2                                   5608516
# 3                                   2336993
# 4                                  31085639
#
#    Census_Total_Workers_Over_16_Estimate  \
# 0                                2055708
# 1                                 337552
# 2                                3155343
# 3                                1297409
# 4                               18399115
#
#   COMMUTE_Census_Worker_Drive_To_Work_Rate  \
# 0                                     0.86
# 1                                     0.68
# 2                                     0.76
# 3                                     0.83
# 4                                     0.74
#
#    COMMUTE_Census_Worker_Carpool_To_Work_Rate  \
# 0                                        0.08
# 1                                        0.12
# 2                                        0.11
# 3                                        0.10
# 4                                        0.10
#
#    COMMUTE_Census_Worker_Public_Transportation_Rate  \
# 0                                              0.00
# 1                                              0.01
# 2                                              0.02
# 3                                              0.00
# 4                                              0.05
#
#    COMMUTE_Census_Worker_Walk_Rate  \
# 0                             0.01
# 1                             0.08
# 2                             0.02
# 3                             0.02
# 4                             0.03
#
#    COMMUTE_Census_Worker_Taxicab_Motorcycle_Bicycle_Other_Rate  \
# 0                                               0.01
# 1                                               0.06
# 2                                               0.03
# 3                                               0.01
# 4                                               0.03
#
#    COMMUTE_Census_Work_At_Home_Rate
# 0                              0.03
# 1                              0.05
# 2                              0.07
# 3                              0.04
# 4                              0.06
#
# [5 rows x 58 columns]

# %%
df.dtypes[df.dtypes == "object"].index.tolist()
# Out:
# ['REGION', 'Area', 'Major_City_CBSA_Title', 'Last_Covid_Update']

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.dropna(inplace=True)

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
df.columns
# Out:
# Index(['REGION', 'Area', 'CENSUS_2010_TOTAL_POPULATION',
#        'CENSUS_2010_STATE_DENSITY', 'Major_City_CBSA_Title',
#        'CBSA_Major_City_Population_2010',
#        'CBSA_Major_City_max_weighted_density',
#        'CBSA_Major_City_mean_pop_density', 'Covid_Positive', 'Covid_Negative',
#        'Covid_Pending', 'Covid_Hospitalized', 'Covid_Death', 'Covid_Total',
#        'Last_Covid_Update', 'FLUVIEW_TOTAL_INFLUENZA_DEATHS_Season_2018',
#        'FLUVIEW_TOTAL_PNEUMONIA_DEATHS_Season_2018',
#        'Kaiser_Total_Hospital_Beds', 'Kaiser_Beds_per_1000_Population',
#        'Kaiser_Total_CHCs', 'Kaiser_CHC_Service_Delivery_Sites',
#        'BRFSS_Asthma_Prevalance', 'Fluview_US_FLU_Hospitalization_Rate_Asthma',
#        'BRFSS_Age_55_64_Asthma_Rate', 'BRFSS_Age_65_plus_Asthma_Rate',
#        'BRFSS_COPD_Prevalance',
#        'Fluview_US_FLU_Hospitalization_Rate_Lung_Disease',
#        'BRFSS_Age_55_64_COPD_Rate', 'BRFSS_Age_65_plus_COPD_Rate',
#        'BRFSS_Heart_Disease_Prevalance',
#        'Fluview_US_FLU_Hospitalization_Rate_Heart_Disease',
#        'BRFSS_Age_55_64_Heart_Disease_Rate',
#        'BRFSS_Age_65_plus_Heart_Disease_Rate',
#        'BRFSS_2017_High_Cholestoral_Prevalance',
#        'BRFSS_2017_High_Blood_Pressure_Prevalance',
#        'BRFSS_Diabetes_Prevalance',
#        'Fluview_US_FLU_Hospitalization_Rate_Metabolic_Disorders',
#        'BRFSS_Age_55_64_Diabetes_Rate', 'BRFSS_Age_65_plus_Diabetes_Rate',
#        'BRFSS_Obesity BMI Prevalance',
#        'Fluview_US_FLU_Hospitalization_Rate_Obesity',
#        'BRFSS_Age_55_64_Obesity_Rate', 'BRFSS_Age_65_plus_Obesity_Rate',
#        'BRFSS_Kidney_Disease_Prevalance',
#        'Fluview_US_FLU_Hospitalization_Rate_Kidney_Disease',
#        'BRFSS_Age_55_64_Kidney_Disease_Rate',
#        'BRFSS_Age_65_plus__Kidney_Disease_Rate',
#        'BRFSS_Other_Cancer_Prevalance', 'BRFSS_55_64_Other_Cancer_Rate',
#        'BRFSS_65_plus_Other_Cancer_Rate',
#        'Census_Total_Population_Over_16_Estimate',
#        'Census_Total_Workers_Over_16_Estimate',
#        'COMMUTE_Census_Worker_Drive_To_Work_Rate',
#        'COMMUTE_Census_Worker_Carpool_To_Work_Rate',
#        'COMMUTE_Census_Worker_Public_Transportation_Rate',
#        'COMMUTE_Census_Worker_Walk_Rate',
#        'COMMUTE_Census_Worker_Taxicab_Motorcycle_Bicycle_Other_Rate',
#        'COMMUTE_Census_Work_At_Home_Rate'],
#       dtype='object')

# %%
X = pd.DataFrame(df, columns=["BRFSS_Asthma_Prevalance","BRFSS_COPD_Prevalance","BRFSS_Heart_Disease_Prevalance","BRFSS_2017_High_Cholestoral_Prevalance",
                             "BRFSS_Diabetes_Prevalance","BRFSS_Obesity BMI Prevalance","BRFSS_Kidney_Disease_Prevalance","BRFSS_Other_Cancer_Prevalance"])
X
# Out:
#     BRFSS_Asthma_Prevalance  BRFSS_COPD_Prevalance  \
# 4                     0.085                  0.046
# 9                     0.087                  0.083
# 11                    0.093                  0.041
# 29                    0.118                  0.080
# 41                    0.079                  0.046
#
#     BRFSS_Heart_Disease_Prevalance  BRFSS_2017_High_Cholestoral_Prevalance  \
# 4                            0.032                                   0.308
# 9                            0.052                                   0.359
# 11                           0.031                                   0.318
# 29                           0.038                                   0.329
# 41                           0.044                                   0.295
#
#     BRFSS_Diabetes_Prevalance  BRFSS_Obesity BMI Prevalance  \
# 4                       0.104                         0.258
# 9                       0.126                         0.307
# 11                      0.115                         0.249
# 29                      0.103                         0.296
# 41                      0.093                         0.301
#
#     BRFSS_Kidney_Disease_Prevalance  BRFSS_Other_Cancer_Prevalance
# 4                             0.029                          0.058
# 9                             0.035                          0.079
# 11                            0.029                          0.059
# 29                            0.025                          0.079
# 41                            0.027                          0.079

# %%
row_names = df["REGION"]
row_names
# Out:
# 4        California
# 9           Florida
# 11           Hawaii
# 29    New Hampshire
# 41     South Dakota
# Name: REGION, dtype: object

# %%
X.shape
# Out:
# (5, 8)

# %%
X.columns
# Out:
# Index(['BRFSS_Asthma_Prevalance', 'BRFSS_COPD_Prevalance',
#        'BRFSS_Heart_Disease_Prevalance',
#        'BRFSS_2017_High_Cholestoral_Prevalance', 'BRFSS_Diabetes_Prevalance',
#        'BRFSS_Obesity BMI Prevalance', 'BRFSS_Kidney_Disease_Prevalance',
#        'BRFSS_Other_Cancer_Prevalance'],
#       dtype='object')

# %%
y = df["Covid_Death"]
y
# Out:
# 4     153
# 9      77
# 11      0
# 29      3
# 41      1
# Name: Covid_Death, dtype: int64

# %%
# creating train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1)

# %% [markdown]
# #### Note:
# * test size is given as 0.3, which means 30% of the data goes into test sets, and train set data contains 70% data. the random state is given for data reproducibility.

# %%
# Creating the scaler instance
from sklearn.preprocessing import StandardScaler
data_scaler = StandardScaler()

# %%
scaled_data = data_scaler.fit(X_train)

# %%
X_train_scaled = scaled_data.transform(X_train)
X_test_scaled = scaled_data.transform(X_test)

# %%
# Create a model with scikit-learn
model = LinearRegression()

# %%
# fitting the model
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
print(y_pred.shape)
# Out:
# (2,)

# %%
results = pd.DataFrame({"Prediction": y_pred, "Actual": y_test})
results.head(5)
# Out:
#     Prediction  Actual
# 11  183.501621       0
# 9    33.520974      77

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11196\3104149303.py in <module>
#       1 from sklearn.metrics import accuracy_score
# ----> 2 accuracy_score(y_test,y_pred)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     209
#     210     # Compute accuracy for each possible representation
# --> 211     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212     check_consistent_length(y_true, y_pred, sample_weight)
#     213     if y_type.startswith("multilabel"):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      93         raise ValueError(
#      94             "Classification metrics can't handle a mix of {0} and {1} targets".format(
# ---> 95                 type_true, type_pred
#      96             )
#      97         )
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %% [markdown]
# ### =============================================================

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
# Choose a learning rate and create classifier
classifier = GradientBoostingClassifier(n_estimators=20,
                                        learning_rate=0.5,
                                        max_features=8,
                                        max_depth=2,
                                        random_state=1)

# Fit the model
classifier.fit(X_train_scaled, y_train)

# Make Prediction
predictions = classifier.predict(X_test_scaled)
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).head(10)
# Out:
#     Prediction  Actual
# 11         153       0
# 9            1      77

# %% [markdown]
# The GradientBoostingClassifier includes the following:
#
# * An array called learning_rates is manually created and contains a range of values.
# * For each learning rate value, a GradientBoostingClassifier model is instantiated.
# * The max_depth argument refers to the size of the decision tree stumps used in gradient boosting.
# * The n_estimators argument refers to the number of trees used.
# * The n_estimators, max_features, and max_depth parameters are fixed at the defined values.
