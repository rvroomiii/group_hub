# %%
import warnings
warnings.filterwarnings('ignore')

# importing modules and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
covid_df = pd.read_csv('Covid_Data.csv')
covid_df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  ICU
# 0               2        2              2        2                     3   97
# 1               2        1              1        2                     5   97
# 2               2        2              2        2                     3    2
# 3               2        2              2        2                     7   97
# 4               2        2              2        2                     3   97
#
# [5 rows x 21 columns]

# %%
covid_df.dtypes[covid_df.dtypes == "object"].index.tolist()
# Out:
# ['DATE_DIED']

# %%
covid_df.shape
# Out:
# (1048575, 21)

# %%
covid_df = covid_df.drop(covid_df[covid_df["PREGNANT"] > 2].index)
covid_df = covid_df.drop(covid_df[covid_df["PNEUMONIA"] > 2].index)

# %%
covid_df = covid_df.drop(['MEDICAL_UNIT', "INTUBED","ICU","USMER",'PATIENT_TYPE', 'CLASIFFICATION_FINAL', 'OTHER_DISEASE'], axis = 1)
covid_df.head()
# Out:
#    SEX   DATE_DIED  PNEUMONIA  AGE  PREGNANT  DIABETES  COPD  ASTHMA  INMSUPR  \
# 0    1  03/05/2020          1   65         2         2     2       2        2
# 3    1  12/06/2020          2   53         2         2     2       2        2
# 5    1  9999-99-99          1   40         2         2     2       2        2
# 6    1  9999-99-99          2   64         2         2     2       2        2
# 7    1  9999-99-99          1   64         2         1     2       2        1
#
#    HIPERTENSION  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO
# 0             1               2        2              2        2
# 3             2               2        2              2        2
# 5             2               2        2              2        2
# 6             2               2        2              2        2
# 7             1               2        2              1        2

# %%
covid_df = covid_df.drop(covid_df[covid_df["DATE_DIED"] == '9999-99-99'].index)

# %%
covid_df
# Out:
#          SEX   DATE_DIED  PNEUMONIA  AGE  PREGNANT  DIABETES  COPD  ASTHMA  \
# 0          1  03/05/2020          1   65         2         2     2       2
# 3          1  12/06/2020          2   53         2         2     2       2
# 153        1  08/05/2020          2    0         2         2     2       2
# 330        1  07/03/2020          2   64         2         2     2       2
# 334        1  27/03/2020          2   49         2         2     2       2
# ...      ...         ...        ...  ...       ...       ...   ...     ...
# 1047628    1  08/07/2020          2   82         2         2     2       2
# 1047629    1  08/07/2020          1   85         2         1     2       2
# 1047632    1  10/07/2020          1   63         2         2     2       2
# 1047634    1  15/07/2020          2   79         2         2     2       2
# 1047637    1  27/07/2020          1   82         2         2     2       2
#
#          INMSUPR  HIPERTENSION  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  \
# 0              2             1               2        2              2
# 3              2             2               2        2              2
# 153            2             2               2        2              2
# 330            2             2               2        2              1
# 334            2             2               2        2              2
# ...          ...           ...             ...      ...            ...
# 1047628        2             2               2        2              2
# 1047629        2             1               2        1              2
# 1047632        2             1               2        2              2
# 1047634        2             1               2        2              2
# 1047637        2             2               2        2              2
#
#          TOBACCO
# 0              2
# 3              2
# 153            2
# 330            2
# 334            2
# ...          ...
# 1047628        2
# 1047629        2
# 1047632        2
# 1047634        2
# 1047637        2
#
# [27029 rows x 14 columns]

# %%
covid_df.dtypes
# Out:
# SEX                int64
# DATE_DIED         object
# PNEUMONIA          int64
# AGE                int64
# PREGNANT           int64
# DIABETES           int64
# COPD               int64
# ASTHMA             int64
# INMSUPR            int64
# HIPERTENSION       int64
# CARDIOVASCULAR     int64
# OBESITY            int64
# RENAL_CHRONIC      int64
# TOBACCO            int64
# dtype: object

# %%
Covid_Disease_df = pd.DataFrame(covid_df, columns =['PNEUMONIA','PREGNANT','DIABETES','COPD','ASTHMA','INMSUPR',
                            'HIPERTENSION','CARDIOVASCULAR','OBESITY','RENAL_CHRONIC',
                            'TOBACCO'])
Covid_Disease_df
# Out:
#          PNEUMONIA  PREGNANT  DIABETES  COPD  ASTHMA  INMSUPR  HIPERTENSION  \
# 0                1         2         2     2       2        2             1
# 3                2         2         2     2       2        2             2
# 153              2         2         2     2       2        2             2
# 330              2         2         2     2       2        2             2
# 334              2         2         2     2       2        2             2
# ...            ...       ...       ...   ...     ...      ...           ...
# 1047628          2         2         2     2       2        2             2
# 1047629          1         2         1     2       2        2             1
# 1047632          1         2         2     2       2        2             1
# 1047634          2         2         2     2       2        2             1
# 1047637          1         2         2     2       2        2             2
#
#          CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO
# 0                     2        2              2        2
# 3                     2        2              2        2
# 153                   2        2              2        2
# 330                   2        2              1        2
# 334                   2        2              2        2
# ...                 ...      ...            ...      ...
# 1047628               2        2              2        2
# 1047629               2        1              2        2
# 1047632               2        2              2        2
# 1047634               2        2              2        2
# 1047637               2        2              2        2
#
# [27029 rows x 11 columns]

# %%
Pneumonia = np.sum(covid_df['PNEUMONIA'] == 1)
print("The number of people who died from Covid AND had pneumonia: ", Pneumonia)
# Out:
# The number of people who died from Covid AND had pneumonia:  18930

# %%
Pregnant = np.sum(covid_df['PREGNANT'] == 1)
print("The number of people who died from Covid AND was pregnant: ", Pregnant)
# Out:
# The number of people who died from Covid AND was pregnant:  89

# %%
Diabetes = np.sum(covid_df['DIABETES'] == 1)
print("The number of people who died from Covid AND had diabetes: ", Diabetes)
# Out:
# The number of people who died from Covid AND had diabetes:  11399

# %%
COPD = np.sum(covid_df['COPD'] == 1)
print("The number of people who died from Covid AND had COPD or Chronic obstructive pulmonary disease: ", COPD)
# Out:
# The number of people who died from Covid AND had COPD or Chronic obstructive pulmonary disease:  1723

# %%
Asthma = np.sum(covid_df['ASTHMA'] == 1)
print("The number of people who died from Covid AND had asthma: ", Asthma)
# Out:
# The number of people who died from Covid AND had asthma:

# %%
Immunocompromised = np.sum(covid_df['INMSUPR'] == 1)
print("The number of people who died from Covid AND was immunocompromised: ", Immunocompromised)
# Out:
# The number of people who died from Covid AND was immunocompromised:  1122

# %%
HIPERTENSION

# %%
CARDIOVASCULAR

# %%
OBESITY

# %%
RENAL_CHRONIC

# %%
TOBACCO
